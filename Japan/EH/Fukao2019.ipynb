# %% [markdown]
# 深尾京司, 牧野達治, & 攝津斉彦. (2019). 日本経済の成長会計分析: 1885-1970 年.

# %%
import tabula

# %%
url = "http://www.ier.hit-u.ac.jp/Common/publication/DP/DPS-A692.pdf" 
tables = tabula.read_pdf(url, pandas_options={'header':3}, pages=23)

# %%
table1 = tables[0][3:].rename(columns={'Unnamed: 0': 'year'})

# %%
table1
# Out:
#     year    (1)       (2)      (3)       (4)      (5)       (6)      (7)  \
# 3   1874  1,011  716.8     427.1    65.3      22.9     201.5     4,044.9
# 4   1875  NaN    NaN       NaN      NaN       NaN      NaN       NaN
# 5   1876  NaN    NaN       NaN      NaN       NaN      NaN       NaN
# 6   1877  NaN    NaN       NaN      NaN       NaN      NaN       NaN
# 7   1878  NaN    NaN       NaN      NaN       NaN      NaN       NaN
# ..   ...  ...    ...       ...      ...       ...      ...       ...
# 65  1936  2,507  21,038.6  3,575.7  6,141.9   1,476.1  7,358.5   2,486.4
# 66  1937  2,563  24,137.7  4,027.4  7,313.6   1,781.9  8,083.6   2,931.2
# 67  1938  2,677  27,686.6  4,219.3  9,837.7   1,896.3  8,574.0   3,159.4
# 68  1939  3,021  34,015.6  6,072.4  12,463.3  2,357.7  9,552.4   3,569.7
# 69  1940  3,071  39,258.8  6,668.0  14,588.9  2,810.6  11,097.3  4,094.0
#
#          (8)      (9)  ...   (28)   (29)   (30)   (31)   (32)   (33)   (34)  \
# ...

# %%
tables = tabula.read_pdf(url,lattice=True,pandas_options={'header':3}, pages=24)
table2 = tables[0][3:].rename(columns={'Unnamed: 0': 'year'}).dropna(axis=1)

# %%
table2
# Out:
#     year    (1)       (6)      (7)       (8)       (9)     (10)    (12)  \
# 3   1937  2,563  14,380.2  3,922.4  2,995.8   7,462.0   70,725   32,156
# 4   1938  2,677  14,671.0  3,739.3  3,515.1   7,416.5   71,103   32,290
# 5   1939  3,021  16,531.7  3,967.1  4,013.6   8,551.1   71,517   32,652
# 6   1940  3,071  16,720.0  3,797.7  4,189.9   8,732.5   71,869   32,942
# 7   1941  3,136  16,951.8  3,499.9  4,392.3   9,059.7   72,218   33,018
# ..   ...    ...       ...      ...      ...       ...      ...      ...
# 32  1966  6,506  47,792.8  5,193.7  17,395.1  25,204.0  99,054   50,806
# 33  1967  7,152  53,473.8  5,213.6  20,093.3  28,166.8  100,243  52,048
# 34  1968  7,983  59,974.2  5,005.2  23,305.1  31,663.9  101,408  52,819
# 35  1969  8,874  67,732.5  4,966.5  27,575.6  35,190.3  102,648  53,563
# 36  1970  9,714  75,759.9  4,488.0  32,672.8  38,599.1  103,720  54,432
#
#       (13)    (14)  ...  (22)   (23)   (24)   (25)   (26)   (27)   (28)  \
# ...
